# %% [markdown]
# <a href="https://colab.research.google.com/github/monikaa947/Upgrad-Learning/blob/main/EDA_Analysis_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic_dataset.csv")

# %%
df.head() #SibSP is the count of sibling or spouse # parch count of parent and children #embarked destination/station
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
100*df.isnull().median()
# Out:
# PassengerId      0.0
# Survived         0.0
# Pclass           0.0
# Name             0.0
# Sex              0.0
# Age              0.0
# SibSp            0.0
# Parch            0.0
# Ticket           0.0
# Fare             0.0
# Cabin          100.0
# Embarked         0.0
# dtype: float64

# %%
df1 = df.drop("Cabin",axis=1)

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
row_mis = df.isnull().sum(axis=0) # check missing value at row level

# %%
row_mis
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
med = df1['Age'].median()
med
# Out:
# 28.0

# %%
df1['Age'] = df1['Age'].fillna(med)

# %%
100*df1.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Embarked       0.224467
# dtype: float64

# %%
df2  = df1[df1['Embarked'].notna()]

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
100*df2.isnull().mean()
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
df2.shape
# Out:
# (889, 11)

# %% [markdown]
# # Univariate Analysis (Analysing single variable/column) expectation is explore each and every variable for analysis

# %%
sns.countplot(x=df2['Sex'])
plt.show()

# %%
sns.histplot(x=df2['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(y=df2['Age'])
# Out:
# <Axes: ylabel='Survived'>

# %%
sns.countplot(x=df2['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# # Bivariant Analysis analysisng 2 varibale

# %% [markdown]
# First combination numeric-numeric variable

# %%
sns.scatterplot(x=df2['Age'],y=df2['Fare'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# First combination numeric-categorical variable

# %%
sns.boxplot(x=df2['Pclass'],y=df2['Age'])
plt.show()

# %%
sns.boxplot(x=df2['SibSp'],y=df2['Age'])
plt.show()

# %%
sns.boxplot(x=df2['Parch'],y=df2['Age'])
plt.show()

# %% [markdown]
# # Multivariant Analysis analysis multiple variables

# %%
sns.heatmap(df2[['Age','Fare','Pclass']].corr(),annot=True)
plt.show()

# %%
runs_df = pd.read_csv("tendulkar_ODI.csv")

# %%
runs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  295 non-null    int64
#  1   Runs        295 non-null    object
#  2   Mins        295 non-null    object
#  3   BF          295 non-null    object
#  4   4s          295 non-null    object
#  5   6s          295 non-null    object
#  6   SR          295 non-null    object
#  7   Pos         295 non-null    object
#  8   Dismissal   295 non-null    object
#  9   Inns        295 non-null    object
#  10  Opposition  295 non-null    object
#  11  Ground      295 non-null    object
#  12  Start Date  295 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 30.1+ KB

# %%
runs_df.head()
# Out:
#    Unnamed: 0 Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0           1    0    -   2  0  0       0   5    caught    2     v Pakistan
# 1           2    0    2   2  0  0       0   5    caught    2  v New Zealand
# 2           3   36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3           4   19   38  35  1  1   54.28   4    bowled    2      v England
# 4           5   31   31  26  3  0  119.23   6    bowled    2      v England
#
#        Ground Start Date
# 0  Gujranwala  18-Dec-89
# 1     Dunedin   1-Mar-90
# 2  Wellington   6-Mar-90
# 3       Leeds  18-Jul-90
# 4  Nottingham  20-Jul-90

# %%
runs_df.shape
# Out:
# (295, 13)

# %%
df_update = runs_df[(runs_df['Runs']!='DNB') & (runs_df['Runs']!='8*')]
df_update = df_update[df_update['4s']!="-"]

# %%
df_update.shape
# Out:
# (291, 13)

# %%
df_update.head()
# Out:
#    Unnamed: 0 Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition  \
# 0           1    0    -   2  0  0       0   5    caught    2     v Pakistan
# 1           2    0    2   2  0  0       0   5    caught    2  v New Zealand
# 2           3   36   51  39  5  0    92.3   6    caught    1  v New Zealand
# 3           4   19   38  35  1  1   54.28   4    bowled    2      v England
# 4           5   31   31  26  3  0  119.23   6    bowled    2      v England
#
#        Ground Start Date
# 0  Gujranwala  18-Dec-89
# 1     Dunedin   1-Mar-90
# 2  Wellington   6-Mar-90
# 3       Leeds  18-Jul-90
# 4  Nottingham  20-Jul-90

# %%
sns.countplot(x=df_update['Runs'], )
# Out:
# <Axes: xlabel='Runs', ylabel='count'>

# %%
sns.histplot(x=df_update['4s'])
# Out:
# <Axes: xlabel='4s', ylabel='Count'>

# %%
news = pd.read_csv("popularity.csv")

# %%
news.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
news.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35857 entries, 0 to 35856
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             35857 non-null  object
#  1    timedelta                      35857 non-null  float64
#  2    n_tokens_title                 35857 non-null  float64
#  3    n_tokens_content               35857 non-null  float64
#  4    n_unique_tokens                35857 non-null  float64
#  5    n_non_stop_words               35857 non-null  float64
#  6    n_non_stop_unique_tokens       35857 non-null  float64
#  7    num_hrefs                      35857 non-null  float64
#  8    num_self_hrefs                 35857 non-null  float64
#  9    num_imgs                       35857 non-null  float64
#  10   num_videos                     35857 non-null  float64
#  11   average_token_length           35857 non-null  float64
# ...

# %%
news.mode(numeric_only=True)
# Out:
#     timedelta   n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0        91.0             10.0                0.0               0.0
#
#     n_non_stop_words   n_non_stop_unique_tokens   num_hrefs   num_self_hrefs  \
# 0                0.0                        0.0         4.0              2.0
#
#     num_imgs   num_videos  ...   min_positive_polarity  \
# 0        1.0          0.0  ...                     0.1
#
#     max_positive_polarity   avg_negative_polarity   min_negative_polarity  \
# 0                     1.0                     0.0                    -0.5
#
#     max_negative_polarity   title_subjectivity   title_sentiment_polarity  \
# 0                   -0.05                  0.0                        0.0
#
#     abs_title_subjectivity   abs_title_sentiment_polarity   shares
# 0                      0.5                            0.0   1100.0
#
# [1 rows x 60 columns]
# ...

# %%
news.mean(numeric_only=True)
# Out:
#  timedelta                           387.700867
#  n_tokens_title                       10.304599
#  n_tokens_content                    546.373037
#  n_unique_tokens                       0.555466
#  n_non_stop_words                      1.006526
#  n_non_stop_unique_tokens              0.696637
#  num_hrefs                            10.933765
#  num_self_hrefs                        3.358424
#  num_imgs                              4.672979
#  num_videos                            1.259336
#  average_token_length                  4.580441
#  num_keywords                          7.247455
#  data_channel_is_lifestyle             0.054160
#  data_channel_is_entertainment         0.177762
#  data_channel_is_bus                   0.161642
#  data_channel_is_socmed                0.061913
#  data_channel_is_tech                  0.191901
#  data_channel_is_world                 0.199347
#  kw_min_min                           28.969657
#  kw_max_min                         1176.222801
# ...

# %%
news.median(numeric_only=True)
# Out:
#  timedelta                           382.000000
#  n_tokens_title                       10.000000
#  n_tokens_content                    407.000000
#  n_unique_tokens                       0.541586
#  n_non_stop_words                      1.000000
#  n_non_stop_unique_tokens              0.692308
#  num_hrefs                             8.000000
#  num_self_hrefs                        3.000000
#  num_imgs                              1.000000
#  num_videos                            0.000000
#  average_token_length                  4.663551
#  num_keywords                          7.000000
#  data_channel_is_lifestyle             0.000000
#  data_channel_is_entertainment         0.000000
#  data_channel_is_bus                   0.000000
#  data_channel_is_socmed                0.000000
#  data_channel_is_tech                  0.000000
#  data_channel_is_world                 0.000000
#  kw_min_min                           -1.000000
#  kw_max_min                          664.000000
# ...

# %%
news['shares']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'shares'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
news.iloc[78]
# Out:
# url                              http://mashable.com/2013/01/07/youtube-vs-cable/
#  timedelta                                                                  731.0
#  n_tokens_title                                                              10.0
#  n_tokens_content                                                          1121.0
#  n_unique_tokens                                                         0.450679
#                                                        ...
#  title_subjectivity                                                           0.0
#  title_sentiment_polarity                                                     0.0
#  abs_title_subjectivity                                                       0.5
#  abs_title_sentiment_polarity                                                 0.0
#  shares                                                                     851.0
# Name: 78, Length: 61, dtype: object

# %%
news.dropna(inplace=True)

# %%
news.describe(include='all')
# Out:
#                                                       url     timedelta  \
# count                                               23928  23928.000000
# unique                                              23928           NaN
# top     http://mashable.com/2013/01/07/amazon-instant-...           NaN
# freq                                                    1           NaN
# mean                                                  NaN    500.145729
# std                                                   NaN    138.327029
# min                                                   NaN    261.000000
# 25%                                                   NaN    381.000000
# 50%                                                   NaN    503.000000
# 75%                                                   NaN    622.000000
# max                                                   NaN    731.000000
#
#          n_tokens_title   n_tokens_content   n_unique_tokens  \
# ...

# %%
df_updated = news[news[' shares']<10800]
# sns.boxplot(y=news[' shares'])
# plt.show()

# %%
df_updated[' shares'].mean()
# Out:
# 2121.9473567892505

# %%
news[' shares'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 23928 entries, 0 to 23927
# Series name:  shares
# Non-Null Count  Dtype
# --------------  -----
# 23928 non-null  float64
# dtypes: float64(1)
# memory usage: 373.9 KB

# %%
df_updated[' shares'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 22624 entries, 0 to 23927
# Series name:  shares
# Non-Null Count  Dtype
# --------------  -----
# 22624 non-null  float64
# dtypes: float64(1)
# memory usage: 353.5 KB

# %%
sns.distplot(news[' shares']);
# Out:
# <ipython-input-33-ce2c4565d74e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(news[' shares']);

# %%
df_updated[' shares'].std()
# Out:
# 1910.61615646574

# %%
nas_df = pd.read_csv("EDA_nas.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-b7aeddfcc0d3> in <cell line: 1>()
# ----> 1 nas_df = pd.read_csv("EDA_nas.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# ...

# %%
nas_df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
nas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STUID                   8801 non-null   int64
#  1   State                   8801 non-null   object
#  2   District                8801 non-null   int64
#  3   Gender                  8799 non-null   object
#  4   Age                     8569 non-null   object
#  5   Category                8232 non-null   float64
#  6   Same.language           8572 non-null   float64
#  7   Siblings                8801 non-null   object
#  8   Handicap                8304 non-null   object
#  9   Father.edu              8147 non-null   object
#  10  Mother.edu              7950 non-null   object
#  11  Father.occupation       7761 non-null   object
#  12  Mother.occupation       6626 non-null   object
#  13  Below.poverty           7347 non-null   object
# ...

# %%
nas_df.dropna(inplace=True)

# %%
nas_df.shape
# Out:
# (0, 64)

# %%
# sns.histplot(y=nas_df['Science..'],x=nas_df['Watch.TV'])
sns.boxplot(x=nas_df['Maths..'],y=nas_df['Father.edu'])
plt.show()

# %%
sns.boxplot(x=nas_df['Play.games'],y=nas_df['Reading..'])
plt.show()

# %%
sns.boxplot(x=nas_df['Science..'],y=nas_df['Watch.TV'])
plt.show()

# %%
sns.boxplot(x=nas_df['Maths..'].mean(),y=nas_df['Solve.Maths'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-05bc157019fb> in <cell line: 1>()
# ----> 1 sns.boxplot(x=nas_df['Maths..'].mean(),y=nas_df['Solve.Maths'])
#
# NameError: name 'sns' is not defined

# %%
census = pd.read_excel("EDA_census.xlsx")

# %%
census.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38',
#        'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42',
#        'Unnamed: 43', 'Unnamed: 44'],
#       dtype='object')

# %%
census.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 6       C2308         00        000      INDIA      Total
# 7       C2308         00        000      INDIA      Total
# 8       C2308         00        000      INDIA      Total
# 9       C2308         00        000      INDIA      Total
# 10      C2308         00        000      INDIA      Total
#
#    C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011  \
# 6                                            All ages
# 7                                                 0-6
# 8                                                   7
# 9                                                   8
# 10                                                  9
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 35 Unnamed: 36  \
# 6   1210854977  623270258  587584719  447216165  ...      345724     7238719
# 7    164515253   85752254   78762999  164515253  ...           0           0
# ...

# %%
census.drop(census.index[:5], inplace=True)

# %%
census.iloc[:, : 16]
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2                         Unnamed: 3  \
# 6         C2308         00        000                              INDIA
# 7         C2308         00        000                              INDIA
# 8         C2308         00        000                              INDIA
# 9         C2308         00        000                              INDIA
# 10        C2308         00        000                              INDIA
# ...         ...        ...        ...                                ...
# 3133      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3134      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3135      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3136      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
# 3137      C2308         35        000  State - ANDAMAN & NICOBAR ISLANDS
#
#      Unnamed: 4  \
# 6         Total
# 7         Total
# 8         Total
# 9         Total
# ...

# %%
new_df = pd.DataFrame({
                        "Table":census['Unnamed: 0'],
                        "State":census['Unnamed: 1'],
                        "District":census['Unnamed: 2'],
                        "Area_Name":census['Unnamed: 3'],
                        "Population":census['Unnamed: 4'],
                        "Age_Group":census['C-8  EDUCATIONAL LEVEL BY AGE AND SEX FOR POPULATION AGE 7 AND ABOVE - 2011'],
                        "Total_Persons":census['Unnamed: 6'],
                        "Total_Males":census['Unnamed: 7'],
                        "Total_Females":census['Unnamed: 8'],
                        "Illiterate_Persons": census['Unnamed: 9'],
                        "Illiterate_Males": census['Unnamed: 10'],
                        "Illiterate_Females": census['Unnamed: 11'],
                        "Literate_Persons": census['Unnamed: 12'],
                        "Literate_Males": census['Unnamed: 13'],
                        "Literate_Females": census['Unnamed: 14']
                      })

# %%
new_df.head()
# Out:
#     Table State District Area_Name Population Age_Group Total_Persons  \
# 6   C2308    00      000     INDIA      Total  All ages    1210854977
# 7   C2308    00      000     INDIA      Total       0-6     164515253
# 8   C2308    00      000     INDIA      Total         7      24826640
# 9   C2308    00      000     INDIA      Total         8      26968373
# 10  C2308    00      000     INDIA      Total         9      23424638
#
#    Total_Males Total_Females Illiterate_Persons Illiterate_Males  \
# 6    623270258     587584719          447216165        188506636
# 7     85752254      78762999          164515253         85752254
# 8     12903364      11923276            6748214          3388683
# 9     14061937      12906436            4131414          2013742
# 10    12214985      11209653            2491904          1198339
#
#    Illiterate_Females Literate_Persons Literate_Males Literate_Females
# 6           258709529        763638812      434763622        328875190
# ...

# %%
new_df.shape
# Out:
# (3132, 15)

# %%
ill_female =

# %%
sns.boxplot(x=new_df['Illiterate_Females'],y=new_df['Total_Females'])
plt.show()
