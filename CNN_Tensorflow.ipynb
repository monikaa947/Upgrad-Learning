# %% [markdown]
# <a href="https://colab.research.google.com/github/monikaa947/Upgrad-Learning/blob/main/CNN_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels),(test_images, test_labels) = datasets.fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_images = train_images.reshape(-1,28,28,1)
test_images = train_images.reshape(-1,28,28,1)

# %%
train_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
train_images, test_images = train_images/255.0, test_images/255.0

# %%
train_images.shape
# Out:
# (60000, 28, 28, 1)

# %%
def plot_sample_images(images,labels,class_name, num_images=5):
  plt.figure(figsize=(10,5))
  for i in range(num_images):
    plt.subplot(1,num_images,i+1)
    plt.imshow(images[i].reshape(28,28),cmap=plt.cm.binary)
    plt.title(class_name[labels[i]])
    plt.axis('off')
  plt.show()

# %%
class_name = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
plot_sample_images(train_images,train_labels,class_name,num_images=9)
